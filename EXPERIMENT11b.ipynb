# %% [markdown]
# Write a Python program to simulate memory allocation (First Fit, Best Fit, Worst Fit).
# >> BEST FIT

# %%
Block =[100,500,200,300,600]
processes =[212,417,112,426]
for p in processes:
    best_index = -1 
    for i in range (len(Block)):
        if Block[i] >= p :
            if best_index == -1 or Block[i] < Block[best_index]:
                best_index = i
    if best_index!=-1:
        print(f" process {p} -> {best_index} allocated")

        Block[best_index]-=p

    else:
        print(f" process {p} -> Not Allocated")
